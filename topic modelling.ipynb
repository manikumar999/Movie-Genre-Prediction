# %% [markdown]
# # Latent Dirichlet Allocation
# ### *It's an unsupervised method used for topic modelling
# ### *The assumption is that each document may contain several topics and each topic may be represented by a group of words. Intuitively, we can think of this as two probabilities
# ### 1.Each document is a distribution of categories. For example, an article that talks about the features of a new phone might have content about the "technology" used in its development, "availability of features", "ease of use".Each of these becomes one category and we can define a distribution of these topics over the document(which category is most talked about is the one with highest probability and so on)
# ### 2.Now to talk about technology, the words that we use would be technical/scientific. So the probability of "LED" to be in the context is higher than for the word say "elections". So, what is derived out is which words are highly probable for the categories

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### *predicting the Genre by using summary can done.
# ### * we may not able to predict the genre by using topic modelling but we can the most important words related to each topic and we can able to relate the topic based on words.

# %%
data=pd.read_csv("moviesdatase.csv",usecols=["overview"])
#data=np.array(data).flatten()

# %%
data=data.iloc[range(10000),:]

# %%
data.fillna(" ",inplace=True)

# %%
data=np.array(data).flatten()

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
def process(doc):
    import re
    stop=stopwords.words('english')
    stemmer= PorterStemmer() 
    doc=re.sub("[\d_]+", " ",doc)
    doc=re.sub("[\W_]+"," ",doc)
    x= word_tokenize(doc)
    x=[i for i in x if len(i)>5]
    #stemmed=[stemmer.stem(word) for word in x]
    clean=[word for word in x if not word in stop]
    joined= ' '.join(clean)
    return joined

# %%
tfidf=TfidfVectorizer(preprocessor=process,decode_error = 'ignore') # Instantiating the tfidf vectorizer

# %%
Doc_term= tfidf.fit_transform(data)
#Doc_term= tfidf.fit_transform(data.astype("U"))

# %%
tfidf.vocabulary_
# Out:
# {'happily': 17240,
#  'birthday': 12001,
#  'brings': 12322,
#  'Lightyear': 5563,
#  'Afraid': 103,
#  'losing': 19181,
#  'circumstances': 12974,
#  'separate': 23523,
#  'eventually': 15795,
#  'learns': 18946,
#  'differences': 14674,
#  'siblings': 23774,
#  'discover': 14807,
#  'enchanted': 15493,
#  'magical': 19262,
#  'unwittingly': 26207,
#  'invite': 18567,
#  'trapped': 25625,
#  'inside': 18293,
#  'living': 19110,
#  'freedom': 16616,
#  'finish': 16338,
#  'proves': 21854,
#  'running': 23098,
#  'rhinoceroses': 22922,
#  'monkeys': 19848,
#  'terrifying': 25261,
#  'creatures': 13944,
#  'family': 16129,
#  'wedding': 26621,
#  'reignites': 22464,
#  'ancient': 11119,
#  'neighbors': 20147,
#  'fishing': 16355,
#  'buddies': 12376,
#  'Meanwhile': 6230,
#  'sultry': 24802,
#  'Italian': 4774,
#  'divorcée': 15011,
#  'restaurant': 22780,
#  'alarming': 10971,
#  'locals': 19125,
#  'interested': 18408,
#  'seafood': 23385,
#  'cooking': 13756,
#  'Cheated': 1863,
#  'mistreated': 19785,
#  'stepped': 24457,
#  'holding': 17506,
#  'breath': 12284,
#  'waiting': 26519,
#  'elusive': 15389,
#  'string': 24610,
#  'stellar': 24450,
#  'lovers': 19200,
#  'Friends': 3605,
#  'confidants': 13486,
#  'Vannah': 9990,
#  'Bernie': 982,
#  'determined': 14588,
#  'better': 11948,
#  'breathe': 12285,
#  'George': 3770,
#  'recovered': 22312,
#  'daughter': 14165,
#  'receives': 22243,
#  'pregnant': 21524,
#  'expecting': 15938,
#  'planning': 21242,
#  'selling': 23482,
#  'change': 12799,
#  'arrival': 11358,
#  'grandchild': 16983,
#  'Obsessive': 6975,
#  'master': 19449,
#  'McCauley': 6144,
#  'various': 26316,
#  'insane': 18276,
#  'heists': 17374,
#  'throughout': 25383,
#  'Angeles': 334,
#  'mentally': 19593,
#  'unstable': 26163,
#  'detective': 14578,
#  'Vincent': 10087,
#  'pursues': 21975,
#  'without': 26765,
#  'recognizes': 22280,
#  'respects': 22768,
#  'ability': 10617,
#  'dedication': 14276,
#  'though': 25347,
#  'violence': 26422,
#  'duckling': 15209,
#  'undergone': 25919,
#  'remarkable': 22548,
#  'harbors': 17249,
#  'feelings': 16218,
#  'carefree': 12617,
#  'playboy': 21262,
#  'business': 12451,
#  'focused': 16455,
#  'brother': 12348,
#  'something': 24108,
#  'mischievous': 19740,
#  'Sawyer': 8383,
#  'witnesses': 26769,
#  'murder': 19979,
#  'deadly': 14186,
#  'becomes': 11833,
#  'friends': 16655,
#  'Huckleberry': 4551,
#  'future': 16732,
#  'choose': 12913,
#  'honoring': 17557,
#  'friendship': 16656,
#  'alcoholic': 10979,
#  'accused': 10717,
#  'several': 23588,
#  'adventures': 10855,
#  'trying': 25754,
#  'retrieve': 22847,
#  'evidence': 15807,
#  'International': 4718,
#  'action': 10751,
#  'superstar': 24855,
#  'Claude': 2012,
#  'Powers': 7564,
#  'Boothe': 1172,
#  'Tension': 9485,
#  'packed': 20730,
#  'suspense': 24956,
#  'thriller': 25368,
#  'Stanley': 9053,
#  'portrays': 21401,
#  'father': 16178,
#  'suddenly': 24772,
#  'championship': 12794,
#  'hockey': 17503,
#  'captors': 12600,
#  'demanding': 14387,
#  'billion': 11982,
#  'dollars': 15046,
#  'frantically': 16602,
#  'motion': 19906,
#  'rescue': 22698,
#  'impending': 17873,
#  'explosion': 15995,
#  'buzzer': 12480,
#  'unmask': 26092,
#  'mysterious': 20030,
#  'Syndicate': 9345,
#  'prevent': 21603,
#  'leader': 18928,
#  'utilizing': 26263,
#  'GoldenEye': 3901,
#  'weapons': 26609,
#  'system': 25061,
#  'inflict': 18171,
#  'devastating': 14604,
#  'revenge': 22874,
#  'Britain': 1320,
#  'Widowed': 10339,
#  'president': 21576,
#  'Andrew': 322,
#  'Shepherd': 8660,
#  'powerful': 21459,
#  'anything': 11213,
#  'covets': 13887,
#  'Sydney': 9336,
#  'Washington': 10220,
#  'lobbyist': 19118,
#  'attempts': 11516,
#  'courting': 13870,
#  'rumors': 23091,
#  'decimate': 14239,
#  'approval': 11281,
#  'ratings': 22141,
#  'lawyer': 18916,
#  'vampire': 26295,
#  'doorstep': 15080,
#  'charms': 12832,
#  'search': 23396,
#  'Helsing': 4336,
#  'vanquish': 26307,
#  'outcast': 20578,
#  'epidemic': 15689,
#  'ravaging': 22151,
#  'Alaska': 149,
#  'powers': 21464,
#  'American': 281,
#  'President': 7597,
#  'Richard': 8040,
#  'carrying': 12649,
#  'shoulders': 23729,
#  'battling': 11799,
#  'destructive': 14564,
#  'demands': 14388,
#  'within': 26764,
#  'Spanning': 8957,
#  'troubled': 25727,
#  'boyhood': 12231,
#  'California': 1502,
#  'shocking': 23692,
#  'Watergate': 10229,
#  'scandal': 23236,
#  'presidency': 21575,
#  'Morgan': 6580,
#  'William': 10365,
#  'recover': 22311,
#  'portions': 21392,
#  'treasure': 25656,
#  'Unfortunately': 9906,
#  'portion': 21391,
#  'murderous': 19984,
#  'skeptical': 23879,
#  'leadership': 18931,
#  'abilities': 10616,
#  'complete': 13365,
#  'mutiny': 20022,
#  'difficult': 14682,
#  'efforts': 15325,
#  'British': 1323,
#  'pirate': 21202,
#  'gambling': 16761,
#  'paradise': 20785,
#  'underbelly': 25906,
#  'Dashwood': 2529,
#  'leaving': 18950,
#  'second': 23412,
#  'daughters': 14166,
#  'inheritance': 18219,
#  'titular': 25434,
#  'opposites': 20487,
#  'Bellhop': 910,
#  'unusual': 26191,
#  'guests': 17119,
#  'outrageous': 20617,
#  'predicaments': 21505,
#  'evening': 15789,
#  'service': 23560,
#  'serving': 23565,
#  'unbelievable': 25847,
#  'happening': 17234,
#  'another': 11175,
#  'Summoned': 9262,
#  'ashram': 11396,
#  'perilous': 21025,
#  'journey': 18686,
#  'jungles': 18717,
#  'Africa': 104,
#  'Shikaka': 8676,
#  'missing': 19773,
#  'sacred': 23126,
#  'animal': 11142,
#  'friendly': 16654,
#  'Wachati': 10156,
#  'accomplish': 10691,
#  'Princess': 7616,
#  'prince': 21627,
#  'warrior': 26569,
#  'Wachootoos': 10157,
#  'result': 22800,
#  'vicious': 26377,
#  'tribal': 25680,
#  'vengeful': 26343,
#  'transit': 25594,
#  'decides': 14237,
#  'trainload': 25560,
#  'subway': 24745,
#  'foster': 16580,
#  'fellow': 16224,
#  'protect': 21822,
#  'Palmer': 7143,
#  'mobster': 19805,
#  'psychopathic': 21898,
#  'Barboni': 743,
#  'collect': 13175,
#  'Hollywood': 4476,
#  'producer': 21695,
#  'specializes': 24193,
#  'cheesy': 12869,
#  'horror': 17598,
#  'leading': 18932,
#  'romantic': 23034,
#  'sparks': 24178,
#  'pitching': 21211,
#  'really': 22191,
#  'different': 14675,
#  'agoraphobic': 10936,
#  'psychologist': 21894,
#  'female': 16229,
#  'together': 25440,
#  'serial': 23548,
#  'killer': 18773,
#  'copies': 13769,
#  'killers': 18774,
#  'Assassin': 535,
#  'Robert': 8092,
#  'arrives': 11362,
#  'funeral': 16716,
#  'prominent': 21755,
#  'witness': 26767,
#  'grisly': 17058,
#  'results': 22803,
#  'Horrified': 4509,
#  'innocent': 18259,
#  'bystanders': 12484,
#  'return': 22852,
#  'civilian': 12983,
#  'finding': 16328,
#  'contract': 13686,
#  'killing': 18776,
#  'dangerous': 14144,
#  'target': 25121,
#  'marked': 19398,
#  'Harassed': 4201,
#  'classmates': 13012,
#  'accept': 10664,
#  'appearance': 11241,
#  'Powder': 7559,
#  'struggles': 24640,
#  'taunts': 25142,
#  'displays': 14903,
#  'allows': 11021,
#  'incredible': 18048,
#  'things': 25325,
#  'phenomenon': 21113,
#  'changes': 12801,
#  'around': 11342,
#  'imagined': 17829,
#  'Sanderson': 8326,
#  'screenwriter': 23351,
#  'everything': 15803,
#  'drinking': 15169,
#  'uneasy': 25977,
#  'interference': 18414,
#  'prostitute': 21816,
#  'pretends': 21594,
#  'friend': 16650,
#  'Othello': 7082,
#  'manipulate': 19347,
#  'version': 26361,
#  'Shakespeare': 8597,
#  'classic': 13005,
#  'Waxing': 10237,
#  'nostalgic': 20272,
#  'bittersweet': 12016,
#  'passage': 20865,
#  'childhood': 12886,
#  'puberty': 21908,
#  'tender': 25230,
#  'coming': 13251,
#  'girlfriends': 16867,
#  'Chrissy': 1933,
#  'Samantha': 8308,
#  'Roberta': 8093,
#  'recall': 22232,
#  'summer': 24805,
#  'During': 2943,
#  'memory': 19580,
#  'reconcile': 22286,
#  'experiences': 15951,
#  'secrets': 23423,
#  'bullies': 12398,
#  'adaptation': 10770,
#  'Austen': 607,
#  'follows': 16473,
#  'Elliot': 3063,
#  'financially': 16323,
#  'aristocratic': 11331,
#  'persuaded': 21077,
#  'engagement': 15552,
#  'Frederick': 3575,
#  'Wentworth': 10275,
#  'captain': 12591,
#  'meager': 19504,
#  'troubles': 25731,
#  'estate': 15757,
#  'Admiral': 70,
#  'thrown': 25387,
#  'company': 13325,
#  'successful': 24756,
#  'perhaps': 21024,
#  'scientist': 23307,
#  'surrealist': 24923,
#  'society': 24068,
#  'kidnaps': 18769,
#  'children': 12892,
#  'dreams': 15152,
#  'hoping': 17579,
#  'process': 21675,
#  'provincial': 21861,
#  'related': 22489,
#  'Shanghai': 8610,
#  'recruited': 22324,
#  'cosmopolitan': 13810,
#  'servant': 23555,
#  'ganglord': 16767,
#  'mistress': 19788,
#  'Former': 3505,
#  'Marine': 5965,
#  'Louanne': 5666,
#  'Johnson': 4923,
#  'teaching': 25153,
#  'program': 21728,
#  'bright': 12314,
#  'underachieving': 25903,
#  'notorious': 20289,
#  'school': 23287,
#  'terrible': 25255,
#  'decorum': 14267,
#  'returns': 22855,
#  'classroom': 13013,
#  'nonsense': 20256,
#  'attitude': 11530,
#  'informed': 18185,
#  'military': 19680,
#  'training': 25559,
#  'fearless': 16202,
#  'determination': 14586,
#  'students': 24650,
#  'matter': 19488,
#  'convict': 13740,
#  'reluctantly': 22537,
#  'volunteers': 26491,
#  'origin': 20551,
#  'nearly': 20106,
#  'population': 21383,
#  'forced': 16504,
#  'survivors': 24948,
#  'underground': 25921,
#  'communities': 13317,
#  'mistakenly': 19783,
#  'instead': 18330,
#  'arrested': 11354,
#  'locked': 19132,
#  'mental': 19591,
#  'hospital': 17605,
#  'psychiatrist': 21884,
#  'Kathryn': 5048,
#  'Railly': 7796,
#  'patient': 20900,
#  'Jeffrey': 4858,
#  'Goines': 3897,
#  'famous': 16131,
#  'expert': 15960,
#  'Monkeys': 6538,
#  'thought': 25348,
#  'responsible': 22777,
#  'unleashing': 26070,
#  'disease': 14827,
#  'little': 19104,
#  'Ferdinand': 3359,
#  'thinks': 25328,
#  'rooster': 23047,
#  'realizes': 22189,
#  'makings': 19301,
#  'become': 11832,
#  'greatest': 17025,
#  'Farmer': 3303,
#  'Hogget': 4461,
#  'relationship': 22494,
#  'painter': 20743,
#  'Carrington': 1652,
#  'author': 11562,
#  'Lytton': 5735,
#  'Strachey': 9155,
#  'England': 3125,
#  'cottages': 13817,
#  'countryside': 13848,
#  'Although': 248,
#  'platonic': 21258,
#  'homosexuality': 17543,
#  'nevertheless': 20179,
#  'complicated': 13377,
#  'develop': 14607,
#  'physical': 21143,
#  'soldier': 24086,
#  'Partridge': 7209,
#  'welcome': 26637,
#  'although': 11045,
#  'remained': 22542,
#  'somewhat': 24112,
#  'lifestyle': 19042,
#  'sexual': 23601,
#  'orientation': 20549,
#  'conscientious': 13558,
#  'objector': 20332,
#  'justice': 18725,
#  'strong': 24626,
#  'teaches': 25152,
#  'forgiveness': 16545,
#  'spirituality': 24255,
#  'accompanies': 10684,
#  'execution': 15879,
#  'Sarandon': 8354,
#  'actress': 10763,
#  'convincing': 13748,
#  'portrayal': 21397,
#  'Sister': 8785,
#  'Prejean': 7582,
#  'Russian': 8234,
#  'Thomas': 9559,
#  'Minton': 6431,
#  'travels': 25647,
#  'passenger': 20868,
#  'freighter': 16631,
#  'Island': 4761,
#  'starts': 24402,
#  'America': 279,
#  'immigrants': 17846,
#  'former': 16557,
#  'searching': 23399,
#  'ancestors': 11111,
#  'emigrated': 15441,
#  'decades': 14216,
#  'letter': 18993,
#  'sample': 23176,
#  'profession': 21708,
#  'Photography': 7383,
#  'relative': 22496,
#  'traces': 25523,
#  'counter': 13832,
#  'checking': 12856,
#  'Photographs': 7382,
#  'antique': 11196,
#  'viewer': 26394,
#  'places': 21224,
#  'audience': 11549,
#  'Identical': 4632,
#  'backgrounds': 11642,
#  'orphaned': 20561,
#  'Amanda': 262,
#  'wealthy': 26605,
#  'Alyssa': 256,
#  'decide': 14234,
#  'switch': 25014,
#  'matchmaker': 19468,
#  'social': 24058,
#  'worker': 26803,
#  'Shallow': 8603,
#  'socially': 24065,
#  'Beverly': 1008,
#  'pecking': 20948,
#  'Seeing': 8509,
#  'coaxes': 13116,
#  'teachers': 25151,
#  'dating': 14164,
#  'Emboldened': 3081,
#  'success': 24754,
#  'hopelessly': 17577,
#  'klutzy': 18800,
#  'student': 24649,
#  'makeover': 19296,
#  'popular': 21378,
#  'disapproving': 14759,
#  'stepbrother': 24452,
#  'misguided': 19758,
#  'African': 105,
#  'preacher': 21484,
#  'wayward': 26600,
#  'committed': 13295,
#  'transplanted': 25611,
#  'setting': 23572,
#  'Depicts': 2648,
#  'retired': 22833,
#  'circulation': 12972,
#  'destined': 14553,
#  'government': 16959,
#  'However': 4539,
#  'broadly': 12334,
#  'addresses': 10787,
#  'issues': 18616,
#  'Americans': 284,
#  'involvement': 18575,
#  'Vietnam': 10073,
#  'subsequent': 24719,
#  'disillusionment': 14853,
#  'progress': 21735,
#  'rights': 22958,
#  'United': 9911,
#  'States': 9080,
#  'aspiring': 11407,
#  'physician': 21145,
#  'Merivel': 6308,
#  'Charles': 1829,
#  'someone': 24106,
#  'provided': 21856,
#  'position': 21404,
#  'ordered': 20521,
#  'divert': 14991,
#  'queens': 22018,
#  'suspicions': 24962,
#  'situation': 23859,
#  'worsens': 26818,
#  'Eventually': 3210,
#  'relieves': 22520,
#  'wealth': 26603,
#  'leaves': 18949,
#  'started': 24398,
#  'reunions': 22857,
#  'rediscovers': 22347,
#  'medicine': 19540,
#  'generations': 16814,
#  'sorcerer': 24121,
#  'victorious': 26384,
#  'battle': 11791,
#  'mortal': 19889,
#  'enemies': 15536,
#  'Mortal': 6607,
#  'Kombat': 5229,
#  'tournament': 25508,
#  'desolation': 14530,
#  'multiverse': 19971,
#  'forever': 16530,
#  'warriors': 26570,
#  'overcome': 20649,
#  'seemingly': 23455,
#  'insurmountable': 18367,
#  'demons': 14404,
#  'superhuman': 24839,
#  'adventure': 10852,
#  'television': 25202,
#  'therefore': 25316,
#  'husband': 17717,
#  'comedy': 13238,
#  'independent': 18072,
#  'director': 14731,
#  'brilliant': 12317,
#  'Nicole': 6878,
#  'Kidman': 5133,
#  'graduate': 16974,
#  'develops': 14615,
#  'suspects': 24953,
#  'fiancé': 16263,
#  'cheating': 12851,
#  'visits': 26455,
#  'grandmother': 16993,
#  'Cleary': 2028,
#  'Grasse': 3983,
#  'members': 19571,
#  'passionate': 20873,
#  'quilters': 22035,
#  'course': 13860,
#  'regaled': 22419,
#  'collected': 13176,
#  'wisdom': 26746,
#  'homicide': 17537,
#  'detectives': 14579,
#  'desperate': 14540,
#  'crimes': 13962,
#  'haunting': 17300,
#  'viewers': 26395,
#  'tortured': 25484,
#  'remains': 22544,
#  'victim': 26380,
#  'seasoned': 23406,
#  'Sommerset': 8911,
#  'researches': 22707,
#  'effort': 15323,
#  'novice': 20298,
#  'partner': 20860,
#  'scoffs': 23312,
#  'unravel': 26123,
#  'History': 4442,
#  'gloriously': 16913,
#  'Disney': 2781,
#  'animated': 11145,
#  'Pocahontas': 7485,
#  'Native': 6774,
#  'arranged': 11348,
#  'village': 26404,
#  'vision': 26446,
#  'prudish': 21874,
#  'working': 26806,
#  'tenure': 25242,
#  'literacy': 19095,
#  'professor': 21713,
#  'university': 26060,
#  'strangely': 24558,
#  'attracted': 11535,
#  'spirited': 24250,
#  'liberal': 19009,
#  'carnival': 12636,
#  'interrogation': 18451,
#  'Verbal': 10028,
#  'convince': 13745,
#  'mythic': 20038,
#  'Keyser': 5122,
#  'exists': 15915,
#  'drawing': 15140,
#  'partners': 20862,
#  'million': 19687,
#  'dollar': 15045,
#  'harbor': 17246,
#  'interrogators': 18453,
#  'almost': 11026,
#  'supernatural': 24849,
#  'prowess': 21870,
#  'Detective': 2682,
#  'turned': 25776,
#  'bodyguard': 12133,
#  'Cynthia': 2437,
#  'Rothrock': 8187,
#  'psychotic': 21904,
#  'seductress': 23446,
#  'Lindell': 5578,
#  'Denier': 2636,
#  'killed': 18772,
#  'months': 19863,
#  'earlier': 15255,
#  'vendetta': 26335,
#  'flamboyantly': 16370,
#  'playful': 21267,
#  'womanizer': 26780,
#  'glamourous': 16883,
#  'protector': 21827,
#  'unique': 26051,
#  'reversal': 22882,
#  'protecting': 21824,
#  'erupting': 15725,
#  'triangle': 25678,
#  'passion': 20872,
#  'genius': 16825,
#  'obsessed': 20358,
#  'biological': 11992,
#  'mother': 19900,
#  'kindhearted': 18780,
#  'reform': 22392,
#  'immoral': 17852,
#  'chorus': 12927,
#  'chimes': 12897,
#  'relate': 22488,
#  'mythology': 20042,
#  'quirky': 22041,
#  'conman': 13536,
#  'Communist': 2138,
#  'Albania': 153,
#  'apprentice': 11272,
#  'factory': 16097,
#  'requires': 22694,
#  'native': 20085,
#  'Albanian': 154,
#  'designate': 14517,
#  'impoverished': 17930,
#  'confused': 13518,
#  'political': 21350,
#  'prisoner': 21644,
#  'chairman': 12779,
#  'project': 21742,
#  'unexpectedly': 25989,
#  'disappears': 14751,
#  'tragic': 25547,
#  'personal': 21062,
#  'history': 17483,
#  'poverty': 21456,
#  'firsthand': 16351,
#  'depressed': 14461,
#  'foreign': 16517,
#  'exchange': 15857,
#  'teacher': 25150,
#  'inject': 18237,
#  'hopeless': 17576,
#  'introducing': 18508,
#  'soccer': 24057,
#  'football': 16488,
#  'assistant': 11445,
#  'overtime': 20702,
#  'esteem': 15759,
#  'involved': 18574,
#  'solving': 24100,
#  'squabbles': 24317,
#  'sister': 23851,
#  'Georgia': 3774,
#  'singer': 23832,
#  'married': 19416,
#  'circuit': 12966,
#  'desperately': 14541,
#  'attraction': 11537,
#  'unwise': 26204,
#  'choice': 12908,
#  'Finally': 3406,
#  'Achilles': 40,
#  'unlovely': 26085,
#  'pleasing': 21281,
#  'singing': 23835,
#  'modern': 19815,
#  'Arthur': 506,
#  'Excalibur': 3222,
#  'worthy': 26831,
#  'making': 19300,
#  'Thanksgiving': 9521,
#  'boyfriend': 12229,
#  'Claudia': 2015,
#  'Larson': 5396,
#  'spending': 24227,
#  'holiday': 17509,
#  'wonders': 26788,
#  'survive': 24943,
#  'antics': 11192,
#  'Simple': 8766,
#  'postman': 21434,
#  'poetry': 21324,
#  'delivering': 14375,
#  'beauty': 11826,
#  'Beatrice': 847,
#  'Quebec': 7742,
#  'Rachel': 7776,
#  'unmarried': 26091,
#  'church': 12943,
#  'Filled': 3398,
#  'unburdens': 25852,
#  'priest': 21617,
#  'confidentiality': 13490,
#  'confessional': 13482,
#  'present': 21563,
#  'Pierre': 7403,
#  'Lamontagne': 5348,
#  'returned': 22853,
#  'attend': 11518,
#  'adopted': 10824,
#  'questioning': 22024,
#  'identity': 17774,
#  'embarked': 15400,
#  'converge': 13724,
#  'complex': 13371,
#  'intrigue': 18501,
#  'answer': 11176,
#  'mystery': 20032,
#  'plastic': 21252,
#  'Indian': 4673,
#  'cupboard': 14067,
#  'befriends': 11854,
#  'brimstone': 12320,
#  'grieving': 17047,
#  'McCann': 6139,
#  'kangaroo': 18740,
#  'monster': 19857,
#  'murdered': 19980,
#  'musician': 19995,
#  'Holland': 4470,
#  'convinced': 13746,
#  'obstacle': 20368,
#  'calling': 12513,
#  'writing': 26863,
#  'historic': 17480,
#  'composition': 13388,
#  'unwritten': 26209,
#  'inspired': 18319,
#  'redefine': 22340,
#  'purpose': 21966,
#  'Ashtray': 526,
#  'Wayans': 10239,
#  'Central': 1757,
#  'appears': 11247,
#  'reefer': 22360,
#  'banging': 11708,
#  'cousin': 13875,
#  'Marlon': 5990,
#  'requisite': 22696,
#  'pistols': 21206,
#  'carries': 12648,
#  'thermo': 25317,
#  'nuclear': 20301,
#  'warhead': 26550,
#  'defense': 14311,
#  'straight': 24544,
#  'girlfriend': 16866,
#  'unsteady': 26164,
#  'involves': 18576,
#  'stealing': 24435,
#  'valuable': 26292,
#  'painting': 20745,
#  'island': 18606,
#  'sagging': 23150,
#  'positive': 21407,
#  'planned': 21239,
#  'losers': 19180,
#  'nothing': 20279,
#  'actively': 10756,
#  'saving': 23219,
#  'environment': 15679,
#  'scientists': 23308,
#  'mission': 19774,
#  'outside': 20624,
#  'contact': 13632,
#  'resuscitated': 22817,
#  'Jonathan': 4932,
#  'Walker': 10178,
#  'create': 13932,
#  'special': 24187,
#  'computer': 13406,
#  'connect': 13538,
#  'computers': 13408,
#  'network': 20166,
#  'control': 13704,
#  'realize': 22187,
#  'teenage': 25181,
#  'hackers': 17166,
#  'Philly': 7374,
#  'Gennaro': 3758,
#  'widowed': 26707,
#  'ailing': 10944,
#  'grandpa': 16994,
#  'quarter': 22014,
#  'promised': 21758,
#  'ticket': 25400,
#  'theater': 25297,
#  'reward': 22916,
#  'unfinished': 26001,
#  'enlists': 15593,
#  'emissary': 15449,
#  'learning': 18945,
#  'infidelities': 18156,
#  'housewife': 17656,
#  'invites': 18569,
#  'itinerant': 18617,
#  'lesbian': 18985,
#  'Smokey': 8857,
#  'hanging': 17224,
#  'Friday': 3599,
#  'afternoon': 10914,
#  'smoking': 23998,
#  'looking': 19169,
#  'younger': 26891,
#  'bloody': 12095,
#  'robbery': 23002,
#  'escape': 15735,
#  'across': 10749,
#  'border': 12182,
#  'Mexico': 6347,
#  'morning': 19885,
#  'kingpin': 18785,
#  'rendezvous': 22593,
#  'Kirkpatrick': 5183,
#  'protects': 21830,
#  'McQuean': 6219,
#  'attorney': 11532,
#  'renegade': 22597,
#  'terminate': 25247,
#  'college': 13187,
#  'graduation': 16978,
#  'Grover': 4053,
#  'moving': 19951,
#  'Prague': 7567,
#  'declines': 14256,
#  'accompany': 10687,
#  'deciding': 14238,
#  'inertia': 18128,
#  'Nobody': 6905,
#  'decisions': 14245,
#  'radically': 22072,
#  'professional': 21709,
#  'studies': 24652,
#  'France': 3538,
#  'illiterate': 17806,
#  'Fortin': 3513,
#  'Belmondo': 914,
#  'introduced': 18506,
#  'Victor': 10062,
#  'Misérables': 6468,
#  'begins': 11864,
#  'parallels': 20794,
#  'planted': 21245,
#  'powered': 21458,
#  'investment': 18555,
#  'banker': 11711,
#  'flowers': 16437,
#  'secret': 23417,
#  'admirer': 10810,
#  'fantasies': 16141,
#  'workaholic': 26800,
#  'sometimes': 24111,
#  'harder': 17255,
#  'conquer': 13548,
#  'writer': 26859,
#  'hometown': 17531,
#  'nemesis': 20155,
#  'ultimately': 25817,
#  'ruined': 23082,
#  'relive': 22526,
#  'painful': 20739,
#  'torturing': 25487,
#  'SIRIUS': 8251,
#  'distant': 14945,
#  'mining': 19710,
#  'planet': 21235,
#  'ravaged': 22149,
#  'decade': 14213,
#  'created': 13933,
#  'perfect': 21005,
#  'weapon': 26606,
#  'wielding': 26712,
#  'replicating': 22645,
#  'devices': 14621,
#  'Screamers': 8470,
#  'designed': 14518,
#  'destroy': 14557,
#  'Christa': 1935,
#  ...}

# %%
Docterms=Doc_term.todense()

# %%
lda = LatentDirichletAllocation(n_components=24, max_iter=200, 
        learning_method='online', random_state=0)

# %%
lda.fit_transform(Docterms)
# Out:
# array([[0.00977284, 0.00977284, 0.00977284, ..., 0.00977284, 0.10613613,
#         0.00977284],
#        [0.00825314, 0.00825314, 0.00825314, ..., 0.00825314, 0.00825314,
#         0.00825314],
#        [0.00828531, 0.00828531, 0.00828531, ..., 0.10566384, 0.00828531,
#         0.00828531],
#        ...,
#        [0.00821896, 0.00821896, 0.00821896, ..., 0.00821896, 0.06869629,
#         0.00821896],
#        [0.00703666, 0.00703666, 0.00703666, ..., 0.00703666, 0.00703666,
#         0.00703666],
#        [0.01394548, 0.01394548, 0.01394548, ..., 0.01394548, 0.01394548,
#         0.01394548]])

# %%
n_top_words = 20
feature_names = tfidf.get_feature_names()

for topic_idx, topic in enumerate(lda.components_):
    print("Topic %d:" % (topic_idx + 1))
    print(" ".join([feature_names[i]
                    for i in topic.argsort()\
                  [:-n_top_words - 1:-1]]))
# Out:
# Topic 1:
# convince vampire church castle vampires pursuing circle Aliens Cornell infatuated impress Woolrich conservative destiny centered dysfunctional Gregory alcohol Antoine stages
# Topic 2:
# interview boring romantically singers fought objections nights Quentin introduced entirely speaking communist Government Shirley choices Kurosawa discuss proper active biopic
# Topic 3:
# Freddy historical suburb necessary ticket Barney monstrous Beijing satanic unbelievable Othello Almodovar measures persona Astronauts cartoon entertain Geoffrey Muriel unpaid
# Topic 4:
# Godzilla terrorizing unknowing marshal protects gunfighter Enterprise devices ravaged factions dystopian Federation Picard barbershop Virgil heists systems recognizes terminate hijacks
# Topic 5:
# employer Steven engage closed artistic Debbie Initially customer Simone Donovan concerts adored freight presided adapts representative Cleopatra Addams Wednesday Factory
# Topic 6:
# eating stakes trilogy Junior upcoming anonymous federal operations barren underwater humiliated higher Queens Seattle feminist amongst spider showgirl horrified quarterback
# Topic 7:
# connected Hannah Ranger Colorado switches Friday skeptical Rangers prospects Lizzie epidemic suburbs highest creepy Daphne everywhere mutiny reflect loyalties poisoned
# Topic 8:
# professional tracks orphanage underground Victor turning strikes Frankenstein gorgeous forest Orleans murderous chronicles Western sentenced instructor comedian convicted Parker treatment
# Topic 9:
# vision Rourke homicide tortured Empire Donald emperor psychopath Mickey affected nightmarish Native protagonist graduates Society Gossett Maurice participate banned Sanada
# Topic 10:
# documentary version Philadelphia investigates claims basketball prince Dracula Indians portrait interviews Shakespeare period memory Americans demons activities Arthur throne Southern
# Topic 11:
# treasure pregnancy afterlife gunslinger runner pharmacies Twelfth bordellos legions surrealist Hawkins delicate gloomy fertility uncles backing Pinhead sagging Casper Steranko
# Topic 12:
# gangster spirit tragedy bizarre estate beauty finding character Broadway strike mansion slowly isolated handsome workers catches General grisly waiting spirited
# Topic 13:
# settle Edward aboard University Martha religion racial Vietnamese robots Monster spacecraft Friends replaced graduation Burton theatrical completed Summer delinquent pageant
# Topic 14:
# Central needing outlandish spouses columnist Jupiter Durant Bourne tendency negative Pancho reconstruct forgets needier propensity Manuelita lodging Singleton giovane Littles
# Topic 15:
# fights Stanley hunters allows cinema stalked dictator Sophie bargained regular painting Yakuza announces raises orphaned persuades prehistoric Turner racing homosexual
# Topic 16:
# upside foster Hawaii physician Shortly gunman Olympic correct Michigan Tromaville unfinished amends disapproving plastic adultery punished Orville advertisement answered nearing
# Topic 17:
# mostly advertising Elliot methods Carmen theatre diamond ghetto astronauts photographs Brazilian Palmer revolt assistance hooker mistakes Lawrence origins report Caesar
# Topic 18:
# Sidney Poitier Carmichael trapping Donahue maneuvers brained hatched Maribelle unspecified warheads braves Deakins cunningly Donahues Anderton Woodsboro Alessandro Nivola directionless
# Topic 19:
# overview Colonel Bishop uptight bandit witted farmers offering cabbage alienated Arnold Thornton Nebraska Ginger motive incompetent garbage Brooks terminal Bennett
# Topic 20:
# family father friends mother becomes daughter American school friend husband murder people become begins together brother police beautiful girlfriend decides
# Topic 21:
# competition daughters Documentary Albert Oliver kingpin antics Australian lessons prostitutes doctors Virginia expatriate homeland Castle quartet smuggle focusing seduced pretending
# Topic 22:
# wedding consequences terrorized suburban Claire cattle safety influence attend cynical riding addictions Secret European Friedrich Francis visited Century literally mobsters
# Topic 23:
# gambler obsession Mother travelling reclusive virgin Gabriel spiritual Watson Church sorcerer occult assumes bodies caretaker smitten Madrid Castro tabloid finance
# Topic 24:
# Daniel gambling Jackie housewife embittered disappeared Hitler suspected Rachel dedicated Pierre Anderson Johnson mutant psychic futuristic discovering Sydney development invention

# %%
lda.components_.shape
# Out:
# (24, 26923)

# %% [markdown]
# # ***LDA using Gensim

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\hp\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: six>=1.5.0 in c:\users\hp\anaconda3\lib\site-packages (from gensim) (1.14.0)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\hp\anaconda3\lib\site-packages (from gensim) (1.4.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\hp\anaconda3\lib\site-packages (from gensim) (1.10.0)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\hp\appdata\roaming\python\python37\site-packages (from gensim) (1.17.4)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.22.0)
# Requirement already satisfied: google-cloud-storage in c:\users\hp\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (1.27.0)
# Requirement already satisfied: boto3 in c:\users\hp\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (1.12.36)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\hp\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.25.8)
# Requirement already satisfied: google-resumable-media<0.6dev,>=0.5.0 in c:\users\hp\anaconda3\lib\site-packages (from google-cloud-storage->smart-open>=1.8.1->gensim) (0.5.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.11.0 in c:\users\hp\anaconda3\lib\site-packages (from google-cloud-storage->smart-open>=1.8.1->gensim) (1.13.1)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.2.0 in c:\users\hp\anaconda3\lib\site-packages (from google-cloud-storage->smart-open>=1.8.1->gensim) (1.3.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\hp\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.9.5)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in c:\users\hp\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.3.3)
# Requirement already satisfied: botocore<1.16.0,>=1.15.36 in c:\users\hp\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (1.15.36)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hp\appdata\roaming\python\python37\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim) (0.2.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\hp\appdata\roaming\python\python37\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim) (3.1.1)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim) (45.2.0.post20200210)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in c:\users\hp\appdata\roaming\python\python37\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim) (4.0)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.16.0 in c:\users\hp\anaconda3\lib\site-packages (from google-cloud-core<2.0dev,>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\hp\anaconda3\lib\site-packages (from botocore<1.16.0,>=1.15.36->boto3->smart-open>=1.8.1->gensim) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from botocore<1.16.0,>=1.15.36->boto3->smart-open>=1.8.1->gensim) (0.15.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\hp\appdata\roaming\python\python37\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim) (0.4.8)
# Requirement already satisfied: pytz in c:\users\hp\anaconda3\lib\site-packages (from google-api-core<2.0.0dev,>=1.16.0->google-cloud-core<2.0dev,>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim) (2019.3)
# Requirement already satisfied: protobuf>=3.4.0 in c:\users\hp\appdata\roaming\python\python37\site-packages (from google-api-core<2.0.0dev,>=1.16.0->google-cloud-core<2.0dev,>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim) (3.11.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from google-api-core<2.0.0dev,>=1.16.0->google-cloud-core<2.0dev,>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim) (1.51.0)

# %%
import gensim
from gensim import corpora

# %%
def process_text(doc):
    stop = stopwords.words('english')
    import re
    input_string=re.sub("[\d_]+", " ",doc)
    input_string=re.sub("[\W_]+"," ",doc)
    Words= [word.lower() for word in word_tokenize(input_string)]
    words= [w for w in Words if not w  in stop]
    return words

# %%
texts=[]
for para in data:
    texts.append(process_text(para))

# %%
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=dictionary,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=10,
                                           passes=10,
                                           alpha='symmetric',
                                           iterations=100,
                                           per_word_topics=True)

# %%
print(lda_model.print_topics())
# Out:
# [(0, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"'), (1, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"'), (2, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"'), (3, '0.109*"world" + 0.095*"father" + 0.091*"years" + 0.085*"three" + 0.057*"set" + 0.057*"back" + 0.037*"living" + 0.033*"discover" + 0.032*"whose" + 0.031*"evil"'), (4, '0.189*"man" + 0.126*"find" + 0.068*"way" + 0.050*"women" + 0.049*"even" + 0.047*"good" + 0.045*"leads" + 0.031*"without" + 0.021*"various" + 0.021*"detective"'), (5, '0.097*"live" + 0.082*"place" + 0.066*"eventually" + 0.065*"heart" + 0.038*"owner" + 0.033*"led" + 0.031*"brings" + 0.031*"put" + 0.027*"room" + 0.026*"learns"'), (6, '0.150*"young" + 0.089*"family" + 0.073*"town" + 0.065*"home" + 0.063*"wife" + 0.052*"daughter" + 0.048*"friends" + 0.043*"becomes" + 0.038*"murder" + 0.034*"boy"'), (7, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"'), (8, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"'), (9, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"'), (10, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"'), (11, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"'), (12, '0.158*"time" + 0.083*"local" + 0.065*"brother" + 0.056*"away" + 0.049*"still" + 0.048*"john" + 0.048*"business" + 0.035*"something" + 0.029*"change" + 0.023*"meanwhile"'), (13, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"'), (14, '0.147*"end" + 0.089*"crew" + 0.070*"may" + 0.012*"thief" + 0.000*"war" + 0.000*"new" + 0.000*"film" + 0.000*"high" + 0.000*"band" + 0.000*"first"'), (15, '0.199*"must" + 0.129*"mysterious" + 0.043*"head" + 0.035*"leader" + 0.018*"prevent" + 0.017*"james" + 0.012*"weapons" + 0.000*"new" + 0.000*"life" + 0.000*"film"'), (16, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"'), (17, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"'), (18, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"'), (19, '0.000*"hobnobbing" + 0.000*"runyonesque" + 0.000*"beggar" + 0.000*"bootlegger" + 0.000*"boozy" + 0.000*"brassy" + 0.000*"née" + 0.000*"runyon" + 0.000*"gruver" + 0.000*"buttons"')]

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        #print(row_list)
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        #print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %% [markdown]
# ### * we can get the information regarding
# ### 1.what is the Document Number
# ### 2. Which topic that particular Document belongs to
# ### 3. what is the contribution of that record to that particular topic.
# ### 4. keywords in that record.

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=texts)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(30)
# Out:
#     Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0             0             5.0              0.9367
# 1             1             3.0              0.7921
# 2             2            12.0              0.8265
# 3             3             4.0              0.8375
# 4             4             6.0              0.7731
# 5             5             4.0              0.7025
# 6             6            12.0              0.8643
# 7             7             6.0              0.9604
# 8             8             3.0              0.8205
# 9             9            15.0              0.8812
# 10           10             3.0              0.5250
# 11           11            14.0              0.3500
# 12           12            15.0              0.3500
# 13           13             3.0              0.4100
# 14           14            14.0              0.4100
# 15           15             0.0              0.0500
# 16           16             6.0              0.5250
# 17           17             5.0              0.6833
# 18           18            15.0              0.2625
# 19           19            12.0              0.5250
# 20           20             5.0              0.5250
# 21           21            15.0              0.3500
# 22           22             4.0              0.3417
# 23           23            15.0              0.2625
# 24           24             6.0              0.5250
# 25           25            14.0              0.3500
# 26           26             3.0              0.5250
# 27           27             6.0              0.5063
# 28           28             0.0              0.0500
# 29           29             6.0              0.6833
#
#                                              Keywords  \
# 0   live, place, eventually, heart, owner, led, br...
# 1   world, father, years, three, set, back, living...
# 2   time, local, brother, away, still, john, busin...
# 3   man, find, way, women, even, good, leads, with...
# 4   young, family, town, home, wife, daughter, fri...
# 5   man, find, way, women, even, good, leads, with...
# 6   time, local, brother, away, still, john, busin...
# 7   young, family, town, home, wife, daughter, fri...
# 8   world, father, years, three, set, back, living...
# 9   must, mysterious, head, leader, prevent, james...
# 10  world, father, years, three, set, back, living...
# 11  end, crew, may, thief, war, new, film, high, b...
# 12  must, mysterious, head, leader, prevent, james...
# 13  world, father, years, three, set, back, living...
# 14  end, crew, may, thief, war, new, film, high, b...
# 15  hobnobbing, runyonesque, beggar, bootlegger, b...
# 16  young, family, town, home, wife, daughter, fri...
# 17  live, place, eventually, heart, owner, led, br...
# 18  must, mysterious, head, leader, prevent, james...
# 19  time, local, brother, away, still, john, busin...
# 20  live, place, eventually, heart, owner, led, br...
# 21  must, mysterious, head, leader, prevent, james...
# 22  man, find, way, women, even, good, leads, with...
# 23  must, mysterious, head, leader, prevent, james...
# 24  young, family, town, home, wife, daughter, fri...
# 25  end, crew, may, thief, war, new, film, high, b...
# 26  world, father, years, three, set, back, living...
# 27  young, family, town, home, wife, daughter, fri...
# 28  hobnobbing, runyonesque, beggar, bootlegger, b...
# 29  young, family, town, home, wife, daughter, fri...
#
#                                                  Text
# 0   [led, woody, andy, toys, live, happily, room, ...
# 1   [siblings, judy, peter, discover, enchanted, b...
# 2   [family, wedding, reignites, ancient, feud, ne...
# 3   [cheated, mistreated, stepped, women, holding,...
# 4   [george, banks, recovered, daughter, wedding, ...
# 5   [obsessive, master, thief, neil, mccauley, lea...
# 6   [ugly, duckling, undergone, remarkable, change...
# 7   [mischievous, young, boy, tom, sawyer, witness...
# 8   [international, action, superstar, jean, claud...
# 9   [james, bond, must, unmask, mysterious, head, ...
# 10  [widowed, u, president, andrew, shepherd, one,...
# 11  [lawyer, shows, vampire, doorstep, falls, prey...
# 12  [outcast, half, wolf, risks, life, prevent, de...
# 13  [star, cast, powers, epic, look, american, pre...
# 14  [morgan, adams, slave, william, shaw, quest, r...
# 15  [life, gambling, paradise, las, vegas, dark, m...
# 16  [rich, mr, dashwood, dies, leaving, second, wi...
# 17  [ted, bellhop, first, night, job, hotel, unusu...
# 18  [summoned, ashram, tibet, ace, finds, perilous...
# 19  [vengeful, new, york, transit, cop, decides, s...
# 20  [chili, palmer, miami, mobster, gets, sent, bo...
# 21  [agoraphobic, psychologist, female, detective,...
# 22  [assassin, robert, rath, arrives, funeral, kil...
# 23  [harassed, classmates, accept, shocking, appea...
# 24  [ben, sanderson, alcoholic, hollywood, screenw...
# 25  [evil, iago, pretends, friend, othello, order,...
# 26  [waxing, nostalgic, bittersweet, passage, chil...
# 27  [film, adaptation, jane, austen, last, novel, ...
# 28  [scientist, surrealist, society, kidnaps, chil...
# 29  [provincial, boy, related, shanghai, crime, fa...
